# %% [markdown]
# <a href="https://colab.research.google.com/github/Yeyeong99/DevJS/blob/main/AI/selfintroduction_feedback.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import os
import csv
from groq import Groq

# %%
client = Groq(api_key='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')
MODEL_NAME = "llama3-70b-8192"

# %%
introduction_feedback = {
    1: {
        'Highlight': 'Spring Boot를 활용한 웹 백엔드 개발 경험',
        'job category': 'Backend',
        'JDReflectRate': '0%',
        'SelfIntroduction':'저는 웹 개발에 큰 관심이 있어 프로그래밍을 배워 왔습니다. Java 언어에 익숙하며, 웹 개발 프레임워크에 대한 배우고 싶은 의지가 있습니다.',
        'Feedback': "5점 만점으로 평가하였을 때 1점입니다.  Spring Boot 개발 경험에 대한 구체적인 내용이 없는 점이 아쉽습니다. '웹 개발에 큰 관심이 있어 프로그래밍을 배워 왔습니다.'와 같은 일반적인 표현보다는, 자신만의 구체적인 경험과 그 경험을 통해 얻은 성과나 배움을 강조하시고, 실무에 어떻게 적용할 수 있을지 반영하면 좋을 것 같습니다."
    },
    2: {
        'Highlight': 'Spring Boot를 활용한 웹 백엔드 개발 경험',
        'job category': 'Backend',
        'JDReflectRate': '25%',
        'SelfIntroduction': '개인 프로젝트에서 Spring Boot를 접하고, 기초적인 웹 백엔드 개발에 사용해보았습니다. REST API 개발과 데이터베이스 연동에 대해 배웠습니다.',
        'Feedback': '5점 만점으로 평가하였을 때 2점입니다. Spring Boot를 사용한 웹 백엔드 개발 경험을 언급하고 있지만, 구체적인 프로젝트나 기술 사용 사례가 부족합니다. 또한, 배운 내용을 어떻게 실무에 적용할 수 있을지에 관한 언급을 하면 더 좋은 자기소개서가 될 것입니다.'
    },
    3: {
        'Highlight': 'AWS 기반 클라우드 환경 구축 경험',
        'job category': 'Cloud',
        'JDReflectRate': '50%',
        'SelfIntroduction': '학부 시절 AWS 클라우드 기초 강의를 수료하고, 졸업 프로젝트로 AWS EC2를 활용한 웹 애플리케이션을 배포했습니다. 이후 AWS Certified Solutions Architect 자격증을 취득하여 AWS 클라우드 환경 구축에 대한 심화된 이해와 실무 경험을 갖추게 되었습니다.',
        'Feedback': '5점 만점으로 평가하였을 때 3점입니다. AWS 클라우드 환경 구축에 대한 기본적인 이해와 경험을 보여주고 있지만, 단순한 나열에 불과하기 때문에 실무에서 어떻게 활용할 지가 명확하지 않습니다. AWS 클라우드 환경 구축 경험을 구체적으로 설명하고, 그 경험을 통해 얻은 성과나 배움을 강조하시면 좋을 것 같습니다.',
    },
    4: {
        'Highlight': 'AWS 기반 클라우드 환경 구축 경험',
        'job category': 'Cloud',
        'JDReflectRate': '75%',
        'SelfIntroduction': '학부 시절 AWS 클라우드를 이용한 웹 서비스를 처음 개발해보았습니다. 서버를 개발한 후 AWS EC2를 활용하여 배포하였고, 이를 통해 EC2 인스턴스를 직접 생성하고, Ubuntu 환경에 Nginx와 Gunicorn을 설치하여 웹 서버를 구성하였으며, 보안 그룹 설정을 통해 인바운드 트래픽을 제어하는 방법을 익혔습니다. 이러한 경험은 실무에서 서비스 운영 환경을 직접 구성하거나, 트래픽 상황에 따라 유연하게 인프라를 조정해야 하는 상황에 있어 큰 도움이 될 수 있을 것이라 확신합니다.',
        'Feedback': "5점 만점으로 평가하였을 때 4점입니다. AWS 클라우드 환경 구축에 대한 구체적인 경험과 그 경험을 통해 얻은 성과나 배움이 구체성을 드러내고 있다는 점에서 긍정적입니다. 다만, 실무에서 어떻게 적용할지에 관한 내용이 비교적 일반적이기 때문에 이 부분을 보완하면 좋을 것 같습니다. 예를 들어, '로드 밸런서와 오토스케일링 그룹을 설정하여 트래픽 부하에 따라 인스턴스를 자동으로 조정하는 구조를 설계하겠습니다'와 같이 구체성이 드러나면 더 좋은 자기소개서가 될 것입니다.",
    },
    5: {
        'Highlight': 'Spring Boot를 활용한 웹 백엔드 개발 경험',
        'job category': 'Backend',
        'JDReflectRate': '100%',
        'SelfIntroduction': '학부 시절 Spring Boot를 활용하여 사용자 맞춤형 금융 상품을 추천하는 웹 백엔드 프로젝트에 참여했습니다. 특히, 대용량의 금융 데이터를 효율적으로 처리하고 어플리케이션의 성능을 향상시키기 위해 람다 표현식과 Stream API를 활용하여 데이터 필터링 및 매핑 과정을 함수형 프로그래밍 방식으로 구현했습니다. 이와 같은 경험으로 실무에서 효율성을 높이는 데에 기여하겠습니다. 예를 들어, 금융 상품 추천 로직처럼 다양한 조건을 기반으로 데이터를 실시간으로 분류 또는 가공해야 할 때, Stream API를 활용한 병렬 처리와 필터링 방식을 이용해 효율을 높이겠습니다. 또한 람다 표현식과 같은 방식으로 중복되는 로직을 간결하게 추상화함으로써, 코드의 유지보수성 향상에 기여하겠습니다.',
        'Feedback': '5점 만점으로 평가하였을 때 5점입니다. Spring Boot를 활용한 웹 백엔드 개발 경험을 구체적으로 설명하고, 관련 기술 (Spring Boot, RESTful API, Swagger) 을 활용한 사례를 제시하며, 고성능 개발에 대한 이해도를 보여주고 있습니다. 또한 앞으로 백엔드 개발자로서 어떠한 면에서 기여할 수 있을지, 특정 상황을 가정하여 구체적으로 답변하고 있는 점이 긍정적으로 평가됩니다.',
    },
}

# %%
PROMPT_TEMPLATE = """
당신은 IT 직무 지원서를 평가할 수 있는 AI를 학습시키기 위한 데이터셋을 생성하고 있습니다.

아래의 직무 키워드를 바탕으로 다음 정보를 한국어로만 생성해주세요.:

1. SelfIntroduction: 제시된 키워드가 {reflect_rate}점 수준으로 반영된 자기소개서를 존댓말로 작성해주세요.
   ({reflect_rate}점 수준은 아래의 예시와 기준 설명을 참고하여, 해당 점수에 정확히 부합하도록 작성해야 합니다.)

2. Feedback: 위 자기소개서에 대한 평가 피드백을 작성해주세요. 1~5점 중 어느 수준인지 평가하고, 개선을 위한 구체적인 조언을 포함하되, 친절하게 답변해주세요.

아래는 {reflect_rate}점 수준의 예시입니다:

SelfIntroduction: {introduction_ex}
Feedback: {feedback_ex}

평가 기준은 다음과 같습니다:

1점 - 단순 언급 수준: 해당 키워드를 단순히 언급하기만 하고, 구체적인 설명이나 경험은 없음.
2점 - 학습 또는 사용 경험 있음: 개인 프로젝트나 수업 등에서 사용했으나 구체적인 맥락이나 실무 적용은 부족.
3점 - 일정 수준의 경험과 예시 있음: 프로젝트 참여와 구체적인 작업이 있지만, 실무적 맥락이나 깊이가 부족.
4점 - 일정 수준의 경험과 예시, 실무에 어떻게 적용할지 방향성이 있음.: 실제 사용 맥락을 담고 있으며, 다만 성과나 실무 적용 방향성은 다소 모호함.
5점 - 구체적인 수준의 경험과 예시, 실무에 어떻게 적용할지 구체적인 방향성이 있음.: 경험에 있어 자신의 기여가 명확히 드러나며, 구체적인 성과를 포함하고 있음. 이러한 성과를 기반으로 실제 업무의 어떤 경우에 어떤 식으로 기여할지 구체적으로 드러냄.

결과는 어떠한 설명도 덧붙이지 말고 아래 JSON 포맷으로 출력해주세요. 줄바꿈 없이 한 줄 JSON으로, 따옴표는 모두 " 로 통일하고, 문자열 안의 따옴표는 escape 처리 해주세요:
{{
  "Highlight": "{highlight}",
  "SelfIntroduction": "...",
  "Feedback": "...",
  "JDReflectRate": {reflect_rate},
  "JobCategory": "{job_category}"
}}
"""

# %%
def generate_data(highlight, job_category, reflect_rate):
    prompt = PROMPT_TEMPLATE.format(
        highlight=highlight,
        reflect_rate=reflect_rate,
        job_category=job_category,
        introduction_ex=introduction_feedback[reflect_rate]['SelfIntroduction'],
        feedback_ex=introduction_feedback[reflect_rate]['Feedback']
    )
    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {"role": "system", "content": "You are an expert assistant for job application writing. You must generate all data only in Korean and in json format without any explanations. DO NOT INCLUDE ANY LANGUAGES WHICH IS NOT KOREAN, SUCH AS HANJI or JAPANESE"},
            {"role": "user", "content": prompt},

            ],
        temperature=0.7
    )

    # JSON 문자열을 안전하게 파싱
    import json
    content = response.choices[0].message.content
    try:
        data = json.loads(content)
        return data
    except json.JSONDecodeError:
        print("JSON 디코딩 실패:\n", content)
        return None

# %%
import csv

filename = '/content/drive/MyDrive/DevJS/데이터 구축_ 예영/4_recent_highlight_jobcategory.csv'
data = []

with open(filename, mode='r', encoding='utf-8-sig') as f:
    reader = csv.reader(f)
    next(reader)  # 헤더 건너뛰기
    for row in reader:
        data.append((row[0], row[1]))

print(data)
# Out:
# [('서버리스 컴퓨팅(Serverless Computing)을 활용한 백엔드 서비스 개발 경험 Backend', 'Backend'), ('Next.js를 활용한 프론트엔드 개발 경험', 'Frontend'), ('PyTorch를 활용한 딥러닝 모델 학습 경험', 'AI/ML'), ('Kubernetes에 대한 운영 경험이 풍부한 분', 'DevOps'), ('Zero Trust Architecture (ZTA) 기반 보안 아키텍처 설계 경험', 'Security'), ('PostgreSQL을 활용한 데이터베이스 설계 경력', 'Database'), ('Flutter 기반 모바일 앱 개발 경험', 'Mobile'), ('Unity 기반 게임 개발 경험', 'Game'), ('Real-Time 운영 체제(RTOS) 경험', 'Embedded'), ('Edge AI 기반 Edge 디바이스 개발 경험', 'IoT'), ('Hyperledger Fabric를 이용한 블록체인 네트워크 구축 경험', 'Blockchain'), ('AR.js를 활용한 가상현실(VR) 개발 경험', 'VR/AR'), ('Pandas를 활용한 데이터 분석과 비즈니스 인텔리전스 경험', 'Data Science'), ('Databricks를 활용한 빅데이터 엔지니어링 경험', 'Data Engineering'), ('Tableau를 활용한 데이터 시각화 경험', 'Data Analysis'), ('D3.js를 활용한 데이터 시각화 엔지니어링 경험', 'Data Visualization'), ('Data Governance Framework 구축 경험 Collibra', 'Data Governance'), ('서버리스 컴퓨팅 기반의 백엔드 서비스 개발 경험', 'Backend'), ('React를 활용한 프론트엔드 개발 경험', 'Frontend'), ('PyTorch를 활용한 딥러닝 모델 최적화 경험.', 'AI/ML'), ('Terraform을 활용한 클라우드 인프라 보장 경험', 'Dev
# ...

# %%
len(data)
# Out:
# 1024

# %%
reflect_levels = [1, 2, 3, 4, 5]

# %%
highlight = data[10][0]
job_category = data[10][1]
for reflect_level in reflect_levels:
    generated_data = generate_data(highlight, job_category, reflect_level)
    print(reflect_level, '___________________________________________________')
    if generate_data != None:
        print(generated_data['SelfIntroduction'])
        print(generated_data['Feedback'])
# Out:
# 1 ___________________________________________________
# 저는 블록체인 기술에 관심이 있어 Hyperledger Fabric를 사용해来了. 블록체인 네트워크 구축에 대한 배우고 싶은 의지가 있습니다.
# 5점 만점으로 평가하였을 때 1점입니다. Hyperledger Fabric를 이용한 구체적인 경험에 대한 설명이 부족합니다. '블록체인 기술에 관심이 있어 Hyperledger Fabric를 사용해来了.'와 같은 일반적인 표현보다는, 자신만의 구체적인 경험과 그 경험을 통해 얻은 성과나 배움을 강조하시고, 실무에 어떻게 적용할 수 있을지 반영하면 좋을 것 같습니다.
# 2 ___________________________________________________
# 저는 Hyperledger Fabric를 이용하여 블록체인 네트워크 구축 프로젝트에 참여하여, 네트워크 구성 요소에 대한 이해를 높였습니다. 또한, 체인코드 개발을 통해 블록체인의 기본 구성 요소를 학습했습니다.
# 5점 만점으로 평가하였을 때 2점입니다. Hyperledger Fabric를 이용한 블록체인 네트워크 구축 경험을 언급하고 있지만, 구체적인 프로젝트의 성과나 실제 업무 적용 방향성이 부족합니다. 이러한 점을 보완하여 실제 업무에 어떻게 적용할지에 대한 언급을 하면 더 좋은 자기소개서가 될 것입니다.
# 3 ___________________________________________________
# 저는 Hyperledger Fabric를 이용한 블록체인 네트워크 구축에 참여하여, 실제 프로젝트에서 이를 적용하여 네트워크의 안정성을 verbess했습니다. 또한,Fabric의 Chaincode 개발에 대한 기본적인 이해를 갖추었습니다.
# ...

# %%
generated_introduction_feedback = []
for highlight, job_category in data:
    for reflect_level in reflect_levels:
        generated_data = generate_data(highlight, job_category, reflect_level)
        print(generated_data)
        if generate_data != None:
            generated_introduction_feedback.append(generated_data)
# Out:
# {'Highlight': '서버리스 컴퓨팅(Serverless Computing)을 활용한 백엔드 서비스 개발 경험 Backend', 'SelfIntroduction': '저는 서버리스 컴퓨팅에 관심이 있어 관련 기술을 공부하고 있습니다. 이 분야에 대한 배움을 지속하고 싶습니다.', 'Feedback': "5점 만점으로 평가하였을 때 1점입니다. 서버리스 컴퓨팅 경험에 대한 구체적인 내용이 없는 점이 아쉽습니다. '서버리스 컴퓨팅에 관심이 있어'와 같은 일반적인 표현보다는, 자신만의 구체적인 경험과 그 경험을 통해 얻은 성과나 배움을 강조하시고, 실무에 어떻게 적용할 수 있을지 반영하면 좋을 것 같습니다.", 'JDReflectRate': 1, 'JobCategory': 'Backend'}
# {'Highlight': '서버리스 컴퓨팅(Serverless Computing)을 활용한 백엔드 서비스 개발 경험 Backend', 'SelfIntroduction': '저는 서버리스 컴퓨팅을 통해 백엔드 서비스 개발에 관심이 있는 개발자입니다. 개인 프로젝트에서 AWS Lambda를 사용해 서버리스 컴퓨팅 방식으로 백엔드 서비스를 개발해본 경험이 있습니다.', 'Feedback': '5점 만점으로 평가하였을 때 2점입니다. 서버리스 컴퓨팅을 활용한 백엔드 서비스 개발 경험을 언급하고 있지만, 구체적인 프로젝트나 기술 사용 사례가 부족합니다. 또한, 배운 내용을 어떻게 실무에 적용할 수 있을지에 관한 언급을 하면 더 좋은 자기소개서가 될 것입니다.', 'JDReflectRate': 2, 'JobCategory': 'Backend'}
# ...

# %%
clean_data = [item for item in generated_introduction_feedback if item is not None]

# %%
clean_data
# Out:
# [{'Highlight': 'Rust를 활용한 백엔드 개발 경험',
#   'SelfIntroduction': '저는 Rust 언어에 관심이 있어 백엔드 개발을 배우고 있습니다. Rust의 기능을 익히고 싶은 의지가 있습니다.',
#   'Feedback': "5점 만점으로 평가하였을 때 1점입니다.  실제 Rust를 활용한 백엔드 개발 경험에 대한 내용이 전혀 없어,  요청된 핵심 역량을 보여주지 못했습니다. 'Rust 언어에 관심이 있어 백엔드 개발을 배우고 있습니다.'와 같은 일반적인 표현보다는, 구체적인 경험과 그 경험을 통해 얻은 성과나 배움을 강조하시고, 실무에 어떻게 적용할 수 있을지 반영하면 좋을 것 같습니다.",
#   'JDReflectRate': 1,
#   'JobCategory': 'Backend'},
#  {'Highlight': 'Rust를 활용한 백엔드 개발 경험',
#   'SelfIntroduction': '개인 프로젝트에서 Rust를 사용하여 백엔드 개발을 경험했으며, 웹 백엔드 개발에 있어 데이터베이스 연동을 구현해보았습니다.',
#   'Feedback': '5점 만점으로 평가하였을 때 2점입니다. Rust를 사용한 백엔드 개발 경험을 언급하고 있지만, 구체적인 프로젝트나 기술 사용 사례가 부족합니다. 또한, 배운 내용을 어떻게 실무에 적용할 수 있을지에 관한 언급이 필요합니다.',
#   'JDReflectRate': 2,
#   'JobCategory': 'Backend'},
#  {'Highlight': 'Rust를 활용한 백엔드 개발 경험',
#   'SelfIntroduction': '학부 시절 Rust 프로그래밍 언어를 학습하고, 졸업 프로젝트로 Rust를 사용하여 웹 애플리케이션의 백엔드를 구현했습니다. 이 프로젝트를 통해 Rust의 안정성과 성능에 대한 기본적인 이해를 갖추게 되었습니다.',
# ...

# %%
import csv
with open("selfintro_dataset2.csv", "w", newline='', encoding='utf-8-sig') as csvfile:
    fieldnames = clean_data[0].keys()
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(clean_data)
